# %%
import xarray as xr

# %%
import netCDF4
print(netCDF4.__version__)

import h5netcdf
print(h5netcdf.__version__)
# Out:
# 1.7.2
# 1.7.3

# %%
ds_003=xr.open_dataset("D:/Man/Earth and Environment/project2/003_2006_2080_352_360.nc")
ds_003.to_dataframe()
# Out:
#                                       TREFMXAV_U       FLNS       FSNS  \
# time                lat       lon
# 2006-01-02 00:00:00 49.476440 352.50         NaN  76.479729  44.470936
#                               353.75         NaN  78.499649  47.310978
#                               355.00         NaN  79.779884  47.081329
#                               356.25         NaN  81.951942  50.421570
#                               357.50         NaN  84.151154  50.305706
# ...                                          ...        ...        ...
# 2080-12-31 00:00:00 58.900524 353.75         NaN  64.274734  12.221095
#                               355.00         NaN  59.831974  10.224747
#                               356.25  285.378082  55.972206   7.803443
#                               357.50         NaN  55.649826   8.590393
#                               358.75         NaN  56.796509   9.985412
#
#                                              PRECT          PRSN      QBOT  \
# ...

# %%
ds_004=xr.open_dataset("D:/Man/Earth and Environment/project2/004_2006_2080_352_360.nc")
ds_004.to_dataframe()
# Out:
#                                       TREFMXAV_U       FLNS       FSNS  \
# time                lat       lon
# 2006-01-02 00:00:00 49.476440 352.50         NaN  34.583336  14.065823
#                               353.75         NaN  31.098053  16.537430
#                               355.00         NaN  25.429327  21.770348
#                               356.25         NaN  21.334295  23.288593
#                               357.50         NaN  14.878189  22.177370
# ...                                          ...        ...        ...
# 2080-12-31 00:00:00 58.900524 353.75         NaN  78.357506  12.646336
#                               355.00         NaN  80.806496  12.415510
#                               356.25  282.256317  77.926613  12.313849
#                               357.50         NaN  73.540985  11.417438
#                               358.75         NaN  65.714958   9.995486
#
#                                              PRECT          PRSN      QBOT  \
# ...
